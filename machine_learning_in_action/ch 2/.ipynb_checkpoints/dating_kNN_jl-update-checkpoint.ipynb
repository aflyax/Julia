# %%
using DataFrames, Distances, Gadfly

# import data

dating_df = readtable("datingTestSet2.txt", separator='\t', header=false);
names!(dating_df, [:miles, :games, :ice_cream, :opinion])
print(head(dating_df))
# Out:
# 6x4 DataFrame
# | Row | miles | games   | ice_cream | opinion |
# |-----|-------|---------|-----------|---------|
# | 1   | 40920 | 8.32698 | 0.953952  | 3       |
# | 2   | 14488 | 7.15347 | 1.6739    | 2       |
# | 3   | 26052 | 1.44187 | 0.805124  | 1       |
# | 4   | 75136 | 13.1474 | 0.428964  | 1       |
# | 5   | 38344 | 1.66979 | 0.134296  | 1       |
# | 6   | 72993 | 10.1417 | 1.03296   | 1       |

# %%
function normalize(input_df::DataFrame, cols::Array{Int})
    norm_df = deepcopy(input_df)
    for i in cols
        norm_df[i] = (input_df[i] - minimum(input_df[i])) / (maximum(input_df[i]) - minimum(input_df[i]))
    end
    norm_df
end

norm_df = normalize(dating_df, [1:3]);
print(head(norm_df))
# Out:
# 6x4 DataFrame
# | Row | miles    | games     | ice_cream | opinion |
# |-----|----------|-----------|-----------|---------|
# | 1   | 0.448325 | 0.398051  | 0.562334  | 3       |
# | 2   | 0.158733 | 0.341955  | 0.987244  | 2       |
# | 3   | 0.285429 | 0.0689252 | 0.474496  | 1       |
# | 4   | 0.823201 | 0.62848   | 0.252489  | 1       |
# | 5   | 0.420102 | 0.0798203 | 0.0785783 | 1       |
# | 6   | 0.799722 | 0.484802  | 0.608961  | 1       |

# %%
function find_kNN(input_array::Array{Float64,1}, set_array::Array{Float64,2}, labels::Array; k=3, prob=false)
    dist = colwise(Euclidean(), set_array', input_array)

    d = Dict{Int,Int}()                   
    for i in labels[sortperm(dist)][1:k]   # key = label, value = counts among k nearest neighbors
        d[i] = get(d, i, 0) + 1
    end
    
    prob || return collect(keys(d))[indmax(collect(values(d)))]   # return the most frequent of neighbors
                                                             # make k an odd value to save the democracy!
    
    d_prob = Dict{Any, Float64}()
    [ d_prob[i] = d[i]/sum(collect(values(d))) for i in keys(d) ]      # {label => probability} dict
    return d_prob
end

function mass_kNN(test_array::Matrix, train_array::Matrix, test_labels::Vector, train_labels::Vector, k::Int64)
    
    count_correct = 0
    for i in 1:size(test_array,1)
        kNN_label = find_kNN(test_array[i,:][:], train_array, train_labels, k = k)
        kNN_label == test_labels[i] ? count_correct += 1 : "pass";
    end    
    return count_correct / size(test_array, 1)
end

function plot_probs(input_array::Matrix, test_portion::Float64, cols::Vector, num_trials::Int64, k::Int64)
    success_rate = Float64[]
    mean_success = Float64[]
    
    data = convert(Matrix{Float64}, input_array[:,cols])
    labels = convert(Vector{Int64}, input_array[:,cols[end]+1])
    
    for i in 1:num_trials
        n = size(input_array,1)
        is_train = shuffle([1:n] .> floor(n * test_portion))
        train_array, test_array = data[is_train,:], data[~is_train,:]
        train_labels, test_labels = labels[is_train], labels[~is_train]
        
        print("*")
        push!(success_rate, mass_kNN(test_array, train_array, test_labels, train_labels, k))
        push!(mean_success, mean(success_rate))
    end

    println("")
#     return num_trials, success_rate
    
#     df = DataFrame(x=1:num_trials, y=success_rate)
    x = [1:num_trials]
    
    ind_df = DataFrame(x=x, y=success_rate, label = "ind. trial")
    mean_df = DataFrame(x=x, y=mean_success, label = "mean rate")
    
#     p = plot(x=x, y=success_rate, Geom.line, Geom.point, Guide.xticks(ticks=x),
#         Guide.xlabel("trial"), Guide.ylabel("accuracy"), Guide.title("kNN runs"), 
#         Theme(default_color=color("seagreen")), label="indiv. trial")
#     q = layer(x=x, y=mean_success, Geom.line, Geom.point,
#         Theme(default_color=color("indianred")), label="mean")

    p = plot(ind_df, x="x", y="y", Geom.line, Geom.point, Guide.xticks(ticks=x),
        Guide.xlabel("trial"), Guide.ylabel("accuracy"), Guide.title("kNN runs"), 
        Theme(default_color=color("seagreen")), color="label")
    q = layer(mean_df, x="x", y="y", Geom.line, Geom.point,
        Theme(default_color=color("indianred")), label="mean", color="label")

    
    append!(p.layers, q);
    display(p)
    
end

norm_array = array(norm_df);
@time plot_probs(norm_array, 0.25, [1:3], 10, 3);

# plot(x=1:num, y=s)
# Out:
# **
# ***
# ****
# *
# key not found: :mean
# while loading In[22], in expression starting on line 56
#
#  in getindex at /home/alex/.julia/v0.3/DataFrames/src/other/index.jl:125
#  in set_mapped_data! at /home/alex/.julia/v0.3/Gadfly/src/Gadfly.jl:252
#  in render at /home/alex/.julia/v0.3/Gadfly/src/Gadfly.jl:430
#  in writemime at /home/alex/.julia/v0.3/Gadfly/src/Gadfly.jl:795
#  in sprint at iostream.jl:229
#  in stringmime at multimedia.jl:71
#  in display at /home/alex/.julia/v0.3/IJulia/src/inline.jl:19
#  in display at /home/alex/.julia/v0.3/Gadfly/src/Gadfly.jl:149
#  in plot_probs at In[22]:68

# %%
x = rand(10)
y = rand(10)
w = rand(10)
z = rand(10)

p = plot(x=x, y=y, Geom.point, Geom.line, Theme(default_color=color("blue")))
q = layer(x=w, y=z, Geom.point, Geom.line, Theme(default_color=color("red")))
append!(p.layers, q);
display(p)
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink"
#      xmlns:gadfly="http://www.gadflyjl.org/ns"
#      version="1.2"
#      width="141.42mm" height="100mm" viewBox="0 0 141.42 100"
#      stroke="none"
#      fill="#000000"
#      stroke-width="0.3"
#      font-size="3.88"
#
#      id="fig-4310bff7f9904cdca2bce4461958f003">
# <g class="plotroot xscalable yscalable" id="fig-4310bff7f9904cdca2bce4461958f003-element-1">
#   <g font-size="4.94" font-family="'PT Sans','Helvetica Neue','Helvetica',sans-serif" fill="#564A55" stroke="none" id="fig-4310bff7f9904cdca2bce4461958f003-element-2">
#     <text x="77.37" y="92" text-anchor="middle">x</text>
#   </g>
#   <g class="guide xlabels" font-size="3.53" font-family="'PT Sans Caption','Helvetica Neue','Helvetica',sans-serif" fill="#6C606B" id="fig-4310bff7f9904cdca2bce4461958f003-element-3">
#     <text x="-150.82" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.5</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.0</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.5</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.0</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.5</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">1.0</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.5</text>
#     <text x="248.52" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.0</text>
#     <text x="305.57" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.5</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-1.00</text>
#     <text x="-88.07" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.95</text>
#     <text x="-82.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.90</text>
#     <text x="-76.66" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.85</text>
#     <text x="-70.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.80</text>
#     <text x="-65.25" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.75</text>
#     <text x="-59.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.70</text>
#     <text x="-53.84" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.65</text>
#     <text x="-48.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.60</text>
#     <text x="-42.43" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.55</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.50</text>
#     <text x="-31.02" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.45</text>
#     <text x="-25.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.40</text>
#     <text x="-19.61" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.35</text>
#     <text x="-13.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.30</text>
#     <text x="-8.2" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.25</text>
#     <text x="-2.5" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.20</text>
#     <text x="3.21" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.15</text>
#     <text x="8.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.10</text>
#     <text x="14.62" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.05</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.00</text>
#     <text x="26.03" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.05</text>
#     <text x="31.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.10</text>
#     <text x="37.44" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.15</text>
#     <text x="43.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.20</text>
#     <text x="48.85" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.25</text>
#     <text x="54.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.30</text>
#     <text x="60.26" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.35</text>
#     <text x="65.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.40</text>
#     <text x="71.67" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.45</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.50</text>
#     <text x="83.08" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.55</text>
#     <text x="88.78" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.60</text>
#     <text x="94.49" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.65</text>
#     <text x="100.19" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.70</text>
#     <text x="105.9" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.75</text>
#     <text x="111.6" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.80</text>
#     <text x="117.31" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.85</text>
#     <text x="123.01" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.90</text>
#     <text x="128.72" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.95</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.00</text>
#     <text x="140.13" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.05</text>
#     <text x="145.83" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.10</text>
#     <text x="151.54" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.15</text>
#     <text x="157.24" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.20</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.25</text>
#     <text x="168.65" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.30</text>
#     <text x="174.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.35</text>
#     <text x="180.06" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.40</text>
#     <text x="185.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.45</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.50</text>
#     <text x="197.18" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.55</text>
#     <text x="202.88" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.60</text>
#     <text x="208.59" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.65</text>
#     <text x="214.29" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.70</text>
#     <text x="219.99" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.75</text>
#     <text x="225.7" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.80</text>
#     <text x="231.4" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.85</text>
#     <text x="237.11" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.90</text>
#     <text x="242.81" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.95</text>
#     <text x="24

# %%
x = [-π:0.1:π]
y = sin(x)
w = cos(x)

pi = round(π, 2)
ticks = [-pi, -pi/2, 0, pi/2, pi]

p = plot(x=x, y=y, Geom.point, Geom.line, Theme(default_color=color("seagreen")), Guide.xticks(ticks=ticks))
q = layer(x=x, y=w, Geom.line, Theme(default_color=color("indianred")))
append!(p.layers, q);

draw(SVGJS("sin-cos.svg", 7.5inch, 3.25inch), p)
p
# Out:
# Plot(...)

# %%
x = rand(2)
y = rand(2)

p = plot(x=x, y=y, Geom.line, Geom.point)

for i in [1:10]
    push!(x, rand())
    push!(y, rand())
    q = layer(x=x, y=w, Geom.line, Theme(default_color=color("indianred")))
    append!(p.layers, q);
    
    display(p)
end
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink"
#      xmlns:gadfly="http://www.gadflyjl.org/ns"
#      version="1.2"
#      width="141.42mm" height="100mm" viewBox="0 0 141.42 100"
#      stroke="none"
#      fill="#000000"
#      stroke-width="0.3"
#      font-size="3.88"
#
#      id="fig-e753cdf510b542a38245245e5bc01ea5">
# <g class="plotroot xscalable yscalable" id="fig-e753cdf510b542a38245245e5bc01ea5-element-1">
#   <g font-size="4.94" font-family="'PT Sans','Helvetica Neue','Helvetica',sans-serif" fill="#564A55" stroke="none" id="fig-e753cdf510b542a38245245e5bc01ea5-element-2">
#     <text x="77.37" y="92" text-anchor="middle">x</text>
#   </g>
#   <g class="guide xlabels" font-size="3.53" font-family="'PT Sans Caption','Helvetica Neue','Helvetica',sans-serif" fill="#6C606B" id="fig-e753cdf510b542a38245245e5bc01ea5-element-3">
#     <text x="-122.3" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.0</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.8</text>
#     <text x="-65.25" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.6</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.4</text>
#     <text x="-8.2" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.2</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.0</text>
#     <text x="48.85" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.2</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.4</text>
#     <text x="105.9" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.6</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.8</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.0</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.2</text>
#     <text x="219.99" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.4</text>
#     <text x="248.52" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.6</text>
#     <text x="277.04" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.8</text>
#     <text x="-100.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.85</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.80</text>
#     <text x="-86.64" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.75</text>
#     <text x="-79.51" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.70</text>
#     <text x="-72.38" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.65</text>
#     <text x="-65.25" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.60</text>
#     <text x="-58.12" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.55</text>
#     <text x="-50.99" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.50</text>
#     <text x="-43.86" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.45</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.40</text>
#     <text x="-29.59" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.35</text>
#     <text x="-22.46" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.30</text>
#     <text x="-15.33" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.25</text>
#     <text x="-8.2" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.20</text>
#     <text x="-1.07" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.15</text>
#     <text x="6.06" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.10</text>
#     <text x="13.19" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.05</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.00</text>
#     <text x="27.45" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.05</text>
#     <text x="34.59" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.10</text>
#     <text x="41.72" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.15</text>
#     <text x="48.85" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.20</text>
#     <text x="55.98" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.25</text>
#     <text x="63.11" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.30</text>
#     <text x="70.24" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.35</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.40</text>
#     <text x="84.5" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.45</text>
#     <text x="91.63" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.50</text>
#     <text x="98.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.55</text>
#     <text x="105.9" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.60</text>
#     <text x="113.03" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.65</text>
#     <text x="120.16" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.70</text>
#     <text x="127.29" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.75</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.80</text>
#     <text x="141.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.85</text>
#     <text x="148.68" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.90</text>
#     <text x="155.81" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.95</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.00</text>
#     <text x="170.08" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.05</text>
#     <text x="177.21" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.10</text>
#     <text x="184.34" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.15</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.20</text>
#     <text x="198.6" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.25</text>
#     <text x="205.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.30</text>
#     <text x="212.86" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.35</text>
#     <text x="219.99" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.40</text>
#     <text x="227.13" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.45</text>
#     <text x="234.26" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.50</text>
#     <text x="241.39" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.55</text>
#     <text x="248.52" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.60</text>
#     <text x="-122.3" y="85.4" text-anchor="middle" gadfly:scale="0.5" visibility="hidden">-1</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="0.5" visibility="hidden">0</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="0.5" visibility="hidden">1</text>
#     <text x="305.57" y="85.4" text-anchor="middle" gadfly:scale="0.5" visibility="hidden">2</text>
#     <text x="-100.91" y="85.4" text-anch
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink"
#      xmlns:gadfly="http://www.gadflyjl.org/ns"
#      version="1.2"
#      width="141.42mm" height="100mm" viewBox="0 0 141.42 100"
#      stroke="none"
#      fill="#000000"
#      stroke-width="0.3"
#      font-size="3.88"
#
#      id="fig-1cbcc1c6b7b04eb793c768c3a448e514">
# <g class="plotroot xscalable yscalable" id="fig-1cbcc1c6b7b04eb793c768c3a448e514-element-1">
#   <g font-size="4.94" font-family="'PT Sans','Helvetica Neue','Helvetica',sans-serif" fill="#564A55" stroke="none" id="fig-1cbcc1c6b7b04eb793c768c3a448e514-element-2">
#     <text x="77.37" y="92" text-anchor="middle">x</text>
#   </g>
#   <g class="guide xlabels" font-size="3.53" font-family="'PT Sans Caption','Helvetica Neue','Helvetica',sans-serif" fill="#6C606B" id="fig-1cbcc1c6b7b04eb793c768c3a448e514-element-3">
#     <text x="-116.59" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.2</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.0</text>
#     <text x="-70.96" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.8</text>
#     <text x="-48.14" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.6</text>
#     <text x="-25.32" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.4</text>
#     <text x="-2.5" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.2</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.0</text>
#     <text x="43.14" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.2</text>
#     <text x="65.96" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.4</text>
#     <text x="88.78" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.6</text>
#     <text x="111.6" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.8</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">1.0</text>
#     <text x="157.24" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.2</text>
#     <text x="180.06" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.4</text>
#     <text x="202.88" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.6</text>
#     <text x="225.7" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.8</text>
#     <text x="248.52" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.0</text>
#     <text x="271.34" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.2</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-1.00</text>
#     <text x="-88.07" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.95</text>
#     <text x="-82.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.90</text>
#     <text x="-76.66" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.85</text>
#     <text x="-70.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.80</text>
#     <text x="-65.25" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.75</text>
#     <text x="-59.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.70</text>
#     <text x="-53.84" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.65</text>
#     <text x="-48.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.60</text>
#     <text x="-42.43" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.55</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.50</text>
#     <text x="-31.02" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.45</text>
#     <text x="-25.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.40</text>
#     <text x="-19.61" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.35</text>
#     <text x="-13.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.30</text>
#     <text x="-8.2" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.25</text>
#     <text x="-2.5" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.20</text>
#     <text x="3.21" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.15</text>
#     <text x="8.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.10</text>
#     <text x="14.62" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.05</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.00</text>
#     <text x="26.03" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.05</text>
#     <text x="31.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.10</text>
#     <text x="37.44" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.15</text>
#     <text x="43.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.20</text>
#     <text x="48.85" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.25</text>
#     <text x="54.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.30</text>
#     <text x="60.26" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.35</text>
#     <text x="65.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.40</text>
#     <text x="71.67" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.45</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.50</text>
#     <text x="83.08" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.55</text>
#     <text x="88.78" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.60</text>
#     <text x="94.49" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.65</text>
#     <text x="100.19" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.70</text>
#     <text x="105.9" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.75</text>
#     <text x="111.6" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.80</text>
#     <text x="117.31" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.85</text>
#     <text x="123.01" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.90</text>
#     <text x="128.72" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.95</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.00</text>
#     <text x="140.13" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.05</text>
#     <text x="145.83" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.10</text>
#     <text x="151.54" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.15</text>
#     <text x="157.24" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.20</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.25</text>
#     <text x="168.65" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.30</text>
#     <text x="174.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.35</text>
#     <text x="180.06" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.40</text>
#     <text x="185.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.45</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.50</text>
#     <text x="197.18" y="85.4" t
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink"
#      xmlns:gadfly="http://www.gadflyjl.org/ns"
#      version="1.2"
#      width="141.42mm" height="100mm" viewBox="0 0 141.42 100"
#      stroke="none"
#      fill="#000000"
#      stroke-width="0.3"
#      font-size="3.88"
#
#      id="fig-6c2ec93c6dae4ef8ab758b157309b76b">
# <g class="plotroot xscalable yscalable" id="fig-6c2ec93c6dae4ef8ab758b157309b76b-element-1">
#   <g font-size="4.94" font-family="'PT Sans','Helvetica Neue','Helvetica',sans-serif" fill="#564A55" stroke="none" id="fig-6c2ec93c6dae4ef8ab758b157309b76b-element-2">
#     <text x="77.37" y="92" text-anchor="middle">x</text>
#   </g>
#   <g class="guide xlabels" font-size="3.53" font-family="'PT Sans Caption','Helvetica Neue','Helvetica',sans-serif" fill="#6C606B" id="fig-6c2ec93c6dae4ef8ab758b157309b76b-element-3">
#     <text x="-122.3" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.25</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.00</text>
#     <text x="-65.25" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.75</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.50</text>
#     <text x="-8.2" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.25</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.00</text>
#     <text x="48.85" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.25</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.50</text>
#     <text x="105.9" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.75</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">1.00</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.25</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.50</text>
#     <text x="219.99" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.75</text>
#     <text x="248.52" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.00</text>
#     <text x="277.04" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.25</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-1.00</text>
#     <text x="-88.07" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.95</text>
#     <text x="-82.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.90</text>
#     <text x="-76.66" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.85</text>
#     <text x="-70.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.80</text>
#     <text x="-65.25" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.75</text>
#     <text x="-59.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.70</text>
#     <text x="-53.84" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.65</text>
#     <text x="-48.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.60</text>
#     <text x="-42.43" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.55</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.50</text>
#     <text x="-31.02" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.45</text>
#     <text x="-25.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.40</text>
#     <text x="-19.61" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.35</text>
#     <text x="-13.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.30</text>
#     <text x="-8.2" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.25</text>
#     <text x="-2.5" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.20</text>
#     <text x="3.21" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.15</text>
#     <text x="8.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.10</text>
#     <text x="14.62" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.05</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.00</text>
#     <text x="26.03" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.05</text>
#     <text x="31.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.10</text>
#     <text x="37.44" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.15</text>
#     <text x="43.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.20</text>
#     <text x="48.85" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.25</text>
#     <text x="54.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.30</text>
#     <text x="60.26" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.35</text>
#     <text x="65.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.40</text>
#     <text x="71.67" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.45</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.50</text>
#     <text x="83.08" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.55</text>
#     <text x="88.78" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.60</text>
#     <text x="94.49" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.65</text>
#     <text x="100.19" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.70</text>
#     <text x="105.9" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.75</text>
#     <text x="111.6" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.80</text>
#     <text x="117.31" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.85</text>
#     <text x="123.01" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.90</text>
#     <text x="128.72" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.95</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.00</text>
#     <text x="140.13" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.05</text>
#     <text x="145.83" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.10</text>
#     <text x="151.54" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.15</text>
#     <text x="157.24" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.20</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.25</text>
#     <text x="168.65" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.30</text>
#     <text x="174.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.35</text>
#     <text x="180.06" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.40</text>
#     <text x="185.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.45</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.50</text>
#     <text x="197.18" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.55</text>
#     <text x="202.88" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.60</text>
#     <text x="208.59" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.65</text>
#     <text x
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink"
#      xmlns:gadfly="http://www.gadflyjl.org/ns"
#      version="1.2"
#      width="141.42mm" height="100mm" viewBox="0 0 141.42 100"
#      stroke="none"
#      fill="#000000"
#      stroke-width="0.3"
#      font-size="3.88"
#
#      id="fig-c1ee0a74f5e94621a9035f31fc98f42e">
# <g class="plotroot xscalable yscalable" id="fig-c1ee0a74f5e94621a9035f31fc98f42e-element-1">
#   <g font-size="4.94" font-family="'PT Sans','Helvetica Neue','Helvetica',sans-serif" fill="#564A55" stroke="none" id="fig-c1ee0a74f5e94621a9035f31fc98f42e-element-2">
#     <text x="77.37" y="92" text-anchor="middle">x</text>
#   </g>
#   <g class="guide xlabels" font-size="3.53" font-family="'PT Sans Caption','Helvetica Neue','Helvetica',sans-serif" fill="#6C606B" id="fig-c1ee0a74f5e94621a9035f31fc98f42e-element-3">
#     <text x="-122.3" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.25</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.00</text>
#     <text x="-65.25" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.75</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.50</text>
#     <text x="-8.2" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.25</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.00</text>
#     <text x="48.85" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.25</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.50</text>
#     <text x="105.9" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.75</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">1.00</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.25</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.50</text>
#     <text x="219.99" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.75</text>
#     <text x="248.52" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.00</text>
#     <text x="277.04" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.25</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-1.00</text>
#     <text x="-88.07" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.95</text>
#     <text x="-82.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.90</text>
#     <text x="-76.66" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.85</text>
#     <text x="-70.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.80</text>
#     <text x="-65.25" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.75</text>
#     <text x="-59.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.70</text>
#     <text x="-53.84" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.65</text>
#     <text x="-48.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.60</text>
#     <text x="-42.43" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.55</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.50</text>
#     <text x="-31.02" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.45</text>
#     <text x="-25.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.40</text>
#     <text x="-19.61" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.35</text>
#     <text x="-13.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.30</text>
#     <text x="-8.2" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.25</text>
#     <text x="-2.5" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.20</text>
#     <text x="3.21" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.15</text>
#     <text x="8.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.10</text>
#     <text x="14.62" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.05</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.00</text>
#     <text x="26.03" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.05</text>
#     <text x="31.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.10</text>
#     <text x="37.44" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.15</text>
#     <text x="43.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.20</text>
#     <text x="48.85" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.25</text>
#     <text x="54.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.30</text>
#     <text x="60.26" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.35</text>
#     <text x="65.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.40</text>
#     <text x="71.67" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.45</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.50</text>
#     <text x="83.08" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.55</text>
#     <text x="88.78" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.60</text>
#     <text x="94.49" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.65</text>
#     <text x="100.19" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.70</text>
#     <text x="105.9" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.75</text>
#     <text x="111.6" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.80</text>
#     <text x="117.31" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.85</text>
#     <text x="123.01" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.90</text>
#     <text x="128.72" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.95</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.00</text>
#     <text x="140.13" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.05</text>
#     <text x="145.83" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.10</text>
#     <text x="151.54" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.15</text>
#     <text x="157.24" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.20</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.25</text>
#     <text x="168.65" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.30</text>
#     <text x="174.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.35</text>
#     <text x="180.06" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.40</text>
#     <text x="185.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.45</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.50</text>
#     <text x="197.18" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.55</text>
#     <text x="202.88" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.60</text>
#     <text x="208.59" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.65</text>
#     <text x
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink"
#      xmlns:gadfly="http://www.gadflyjl.org/ns"
#      version="1.2"
#      width="141.42mm" height="100mm" viewBox="0 0 141.42 100"
#      stroke="none"
#      fill="#000000"
#      stroke-width="0.3"
#      font-size="3.88"
#
#      id="fig-5f720da8645344eb86dd2a516fef02b9">
# <g class="plotroot xscalable yscalable" id="fig-5f720da8645344eb86dd2a516fef02b9-element-1">
#   <g font-size="4.94" font-family="'PT Sans','Helvetica Neue','Helvetica',sans-serif" fill="#564A55" stroke="none" id="fig-5f720da8645344eb86dd2a516fef02b9-element-2">
#     <text x="77.37" y="92" text-anchor="middle">x</text>
#   </g>
#   <g class="guide xlabels" font-size="3.53" font-family="'PT Sans Caption','Helvetica Neue','Helvetica',sans-serif" fill="#6C606B" id="fig-5f720da8645344eb86dd2a516fef02b9-element-3">
#     <text x="-150.82" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.5</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.0</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.5</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.0</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.5</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">1.0</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.5</text>
#     <text x="248.52" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.0</text>
#     <text x="305.57" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.5</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-1.00</text>
#     <text x="-88.07" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.95</text>
#     <text x="-82.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.90</text>
#     <text x="-76.66" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.85</text>
#     <text x="-70.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.80</text>
#     <text x="-65.25" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.75</text>
#     <text x="-59.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.70</text>
#     <text x="-53.84" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.65</text>
#     <text x="-48.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.60</text>
#     <text x="-42.43" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.55</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.50</text>
#     <text x="-31.02" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.45</text>
#     <text x="-25.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.40</text>
#     <text x="-19.61" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.35</text>
#     <text x="-13.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.30</text>
#     <text x="-8.2" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.25</text>
#     <text x="-2.5" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.20</text>
#     <text x="3.21" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.15</text>
#     <text x="8.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.10</text>
#     <text x="14.62" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.05</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.00</text>
#     <text x="26.03" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.05</text>
#     <text x="31.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.10</text>
#     <text x="37.44" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.15</text>
#     <text x="43.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.20</text>
#     <text x="48.85" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.25</text>
#     <text x="54.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.30</text>
#     <text x="60.26" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.35</text>
#     <text x="65.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.40</text>
#     <text x="71.67" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.45</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.50</text>
#     <text x="83.08" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.55</text>
#     <text x="88.78" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.60</text>
#     <text x="94.49" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.65</text>
#     <text x="100.19" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.70</text>
#     <text x="105.9" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.75</text>
#     <text x="111.6" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.80</text>
#     <text x="117.31" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.85</text>
#     <text x="123.01" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.90</text>
#     <text x="128.72" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.95</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.00</text>
#     <text x="140.13" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.05</text>
#     <text x="145.83" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.10</text>
#     <text x="151.54" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.15</text>
#     <text x="157.24" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.20</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.25</text>
#     <text x="168.65" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.30</text>
#     <text x="174.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.35</text>
#     <text x="180.06" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.40</text>
#     <text x="185.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.45</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.50</text>
#     <text x="197.18" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.55</text>
#     <text x="202.88" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.60</text>
#     <text x="208.59" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.65</text>
#     <text x="214.29" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.70</text>
#     <text x="219.99" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.75</text>
#     <text x="225.7" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.80</text>
#     <text x="231.4" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.85</text>
#     <text x="237.11" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.90</text>
#     <text x="242.81" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.95</text>
#     <text x="24
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink"
#      xmlns:gadfly="http://www.gadflyjl.org/ns"
#      version="1.2"
#      width="141.42mm" height="100mm" viewBox="0 0 141.42 100"
#      stroke="none"
#      fill="#000000"
#      stroke-width="0.3"
#      font-size="3.88"
#
#      id="fig-65d7ff0132644201a34ec82f18027afd">
# <g class="plotroot xscalable yscalable" id="fig-65d7ff0132644201a34ec82f18027afd-element-1">
#   <g font-size="4.94" font-family="'PT Sans','Helvetica Neue','Helvetica',sans-serif" fill="#564A55" stroke="none" id="fig-65d7ff0132644201a34ec82f18027afd-element-2">
#     <text x="77.37" y="92" text-anchor="middle">x</text>
#   </g>
#   <g class="guide xlabels" font-size="3.53" font-family="'PT Sans Caption','Helvetica Neue','Helvetica',sans-serif" fill="#6C606B" id="fig-65d7ff0132644201a34ec82f18027afd-element-3">
#     <text x="-150.82" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.5</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.0</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.5</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.0</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.5</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">1.0</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.5</text>
#     <text x="248.52" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.0</text>
#     <text x="305.57" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.5</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-1.00</text>
#     <text x="-88.07" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.95</text>
#     <text x="-82.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.90</text>
#     <text x="-76.66" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.85</text>
#     <text x="-70.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.80</text>
#     <text x="-65.25" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.75</text>
#     <text x="-59.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.70</text>
#     <text x="-53.84" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.65</text>
#     <text x="-48.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.60</text>
#     <text x="-42.43" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.55</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.50</text>
#     <text x="-31.02" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.45</text>
#     <text x="-25.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.40</text>
#     <text x="-19.61" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.35</text>
#     <text x="-13.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.30</text>
#     <text x="-8.2" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.25</text>
#     <text x="-2.5" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.20</text>
#     <text x="3.21" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.15</text>
#     <text x="8.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.10</text>
#     <text x="14.62" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.05</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.00</text>
#     <text x="26.03" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.05</text>
#     <text x="31.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.10</text>
#     <text x="37.44" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.15</text>
#     <text x="43.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.20</text>
#     <text x="48.85" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.25</text>
#     <text x="54.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.30</text>
#     <text x="60.26" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.35</text>
#     <text x="65.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.40</text>
#     <text x="71.67" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.45</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.50</text>
#     <text x="83.08" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.55</text>
#     <text x="88.78" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.60</text>
#     <text x="94.49" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.65</text>
#     <text x="100.19" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.70</text>
#     <text x="105.9" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.75</text>
#     <text x="111.6" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.80</text>
#     <text x="117.31" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.85</text>
#     <text x="123.01" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.90</text>
#     <text x="128.72" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.95</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.00</text>
#     <text x="140.13" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.05</text>
#     <text x="145.83" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.10</text>
#     <text x="151.54" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.15</text>
#     <text x="157.24" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.20</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.25</text>
#     <text x="168.65" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.30</text>
#     <text x="174.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.35</text>
#     <text x="180.06" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.40</text>
#     <text x="185.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.45</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.50</text>
#     <text x="197.18" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.55</text>
#     <text x="202.88" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.60</text>
#     <text x="208.59" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.65</text>
#     <text x="214.29" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.70</text>
#     <text x="219.99" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.75</text>
#     <text x="225.7" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.80</text>
#     <text x="231.4" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.85</text>
#     <text x="237.11" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.90</text>
#     <text x="242.81" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.95</text>
# ...
# <svg xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink"
#      xmlns:gadfly="http://www.gadflyjl.org/ns"
#      version="1.2"
#      width="141.42mm" height="100mm" viewBox="0 0 141.42 100"
#      stroke="none"
#      fill="#000000"
#      stroke-width="0.3"
#      font-size="3.88"
#
#      id="fig-d42f9da4dafd4731b8d340a23116973b">
# <g class="plotroot xscalable yscalable" id="fig-d42f9da4dafd4731b8d340a23116973b-element-1">
#   <g font-size="4.94" font-family="'PT Sans','Helvetica Neue','Helvetica',sans-serif" fill="#564A55" stroke="none" id="fig-d42f9da4dafd4731b8d340a23116973b-element-2">
#     <text x="77.37" y="92" text-anchor="middle">x</text>
#   </g>
#   <g class="guide xlabels" font-size="3.53" font-family="'PT Sans Caption','Helvetica Neue','Helvetica',sans-serif" fill="#6C606B" id="fig-d42f9da4dafd4731b8d340a23116973b-element-3">
#     <text x="-150.82" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.5</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.0</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.5</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.0</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.5</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">1.0</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.5</text>
#     <text x="248.52" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.0</text>
#     <text x="305.57" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.5</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-1.00</text>
#     <text x="-88.07" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.95</text>
#     <text x="-82.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.90</text>
#     <text x="-76.66" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.85</text>
#     <text x="-70.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.80</text>
#     <text x="-65.25" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.75</text>
#     <text x="-59.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.70</text>
#     <text x="-53.84" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.65</text>
#     <text x="-48.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.60</text>
#     <text x="-42.43" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.55</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.50</text>
#     <text x="-31.02" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.45</text>
#     <text x="-25.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.40</text>
#     <text x="-19.61" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.35</text>
#     <text x="-13.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.30</text>
#     <text x="-8.2" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.25</text>
#     <text x="-2.5" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.20</text>
#     <text x="3.21" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.15</text>
#     <text x="8.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.10</text>
#     <text x="14.62" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.05</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.00</text>
#     <text x="26.03" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.05</text>
#     <text x="31.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.10</text>
#     <text x="37.44" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.15</text>
#     <text x="43.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.20</text>
#     <text x="48.85" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.25</text>
#     <text x="54.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.30</text>
#     <text x="60.26" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.35</text>
#     <text x="65.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.40</text>
#     <text x="71.67" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.45</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.50</text>
#     <text x="83.08" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.55</text>
#     <text x="88.78" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.60</text>
#     <text x="94.49" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.65</text>
#     <text x="100.19" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.70</text>
#     <text x="105.9" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.75</text>
#     <text x="111.6" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.80</text>
#     <text x="117.31" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.85</text>
#     <text x="123.01" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.90</text>
#     <text x="128.72" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.95</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.00</text>
#     <text x="140.13" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.05</text>
#     <text x="145.83" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.10</text>
#     <text x="151.54" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.15</text>
#     <text x="157.24" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.20</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.25</text>
#     <text x="168.65" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.30</text>
#     <text x="174.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.35</text>
#     <text x="180.06" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.40</text>
#     <text x="185.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.45</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.50</text>
#     <text x="197.18" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.55</text>
#     <text x="202.88" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.60</text>
#     <text x="208.59" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.65</text>
#     <text x="214.29" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.70</text>
#     <text x="219.99" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.75</text>
#     <text x="225.7" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.80</text>
#     <text x="231.4" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.85</text>
#     <text x="237.11" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.90</text>
#     <text x="242.81" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.95</text>
#     <text x="24
# <?xml version="1.0" encoding="UTF-8"?>
# <svg xmlns="http://www.w3.org/2000/svg"
#      xmlns:xlink="http://www.w3.org/1999/xlink"
#      xmlns:gadfly="http://www.gadflyjl.org/ns"
#      version="1.2"
#      width="141.42mm" height="100mm" viewBox="0 0 141.42 100"
#      stroke="none"
#      fill="#000000"
#      stroke-width="0.3"
#      font-size="3.88"
#
#      id="fig-b85466b56ded4a98aa92b028ce5039c0">
# <g class="plotroot xscalable yscalable" id="fig-b85466b56ded4a98aa92b028ce5039c0-element-1">
#   <g font-size="4.94" font-family="'PT Sans','Helvetica Neue','Helvetica',sans-serif" fill="#564A55" stroke="none" id="fig-b85466b56ded4a98aa92b028ce5039c0-element-2">
#     <text x="77.37" y="92" text-anchor="middle">x</text>
#   </g>
#   <g class="guide xlabels" font-size="3.53" font-family="'PT Sans Caption','Helvetica Neue','Helvetica',sans-serif" fill="#6C606B" id="fig-b85466b56ded4a98aa92b028ce5039c0-element-3">
#     <text x="-150.82" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.5</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-1.0</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">-0.5</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.0</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">0.5</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="visible">1.0</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">1.5</text>
#     <text x="248.52" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.0</text>
#     <text x="305.57" y="85.4" text-anchor="middle" gadfly:scale="1.0" visibility="hidden">2.5</text>
#     <text x="-93.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-1.00</text>
#     <text x="-88.07" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.95</text>
#     <text x="-82.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.90</text>
#     <text x="-76.66" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.85</text>
#     <text x="-70.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.80</text>
#     <text x="-65.25" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.75</text>
#     <text x="-59.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.70</text>
#     <text x="-53.84" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.65</text>
#     <text x="-48.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.60</text>
#     <text x="-42.43" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.55</text>
#     <text x="-36.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.50</text>
#     <text x="-31.02" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.45</text>
#     <text x="-25.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.40</text>
#     <text x="-19.61" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.35</text>
#     <text x="-13.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.30</text>
#     <text x="-8.2" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.25</text>
#     <text x="-2.5" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.20</text>
#     <text x="3.21" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.15</text>
#     <text x="8.91" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.10</text>
#     <text x="14.62" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">-0.05</text>
#     <text x="20.32" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.00</text>
#     <text x="26.03" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.05</text>
#     <text x="31.73" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.10</text>
#     <text x="37.44" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.15</text>
#     <text x="43.14" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.20</text>
#     <text x="48.85" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.25</text>
#     <text x="54.55" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.30</text>
#     <text x="60.26" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.35</text>
#     <text x="65.96" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.40</text>
#     <text x="71.67" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.45</text>
#     <text x="77.37" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.50</text>
#     <text x="83.08" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.55</text>
#     <text x="88.78" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.60</text>
#     <text x="94.49" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.65</text>
#     <text x="100.19" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.70</text>
#     <text x="105.9" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.75</text>
#     <text x="111.6" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.80</text>
#     <text x="117.31" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.85</text>
#     <text x="123.01" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.90</text>
#     <text x="128.72" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">0.95</text>
#     <text x="134.42" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.00</text>
#     <text x="140.13" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.05</text>
#     <text x="145.83" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.10</text>
#     <text x="151.54" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.15</text>
#     <text x="157.24" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.20</text>
#     <text x="162.95" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.25</text>
#     <text x="168.65" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.30</text>
#     <text x="174.36" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.35</text>
#     <text x="180.06" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.40</text>
#     <text x="185.77" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.45</text>
#     <text x="191.47" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.50</text>
#     <text x="197.18" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.55</text>
#     <text x="202.88" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.60</text>
#     <text x="208.59" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.65</text>
#     <text x="214.29" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.70</text>
#     <text x="219.99" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.75</text>
#     <text x="225.7" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.80</text>
#     <text x="231.4" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.85</text>
#     <text x="237.11" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.90</text>
#     <text x="242.81" y="85.4" text-anchor="middle" gadfly:scale="10.0" visibility="hidden">1.95</text>
#     <text x="24
